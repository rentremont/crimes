# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crimes_df = pd.read_csv('../../data/crimes.dataset.csv')

# %%
crimes_df
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
crimes_df=crimes_df.rename(columns={'Rape\n(revised\ndefinition)':'Rape_revised','Rape\n(revised\ndefinition)\nrate':'Rape_revised_rate', 'Rape\n(legacy\ndefinition':'Rape', 'Rape\n(legacy\ndefinition)\nrate': 'Rape_rate'})
crimes_df
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
crimes_df
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
crimes_df=crimes_df.rename(columns={'Robbery\nrate':'Robbery_rate','Aggravated\nassault':'Aggravated_assault', 'Aggravated\nassault rate':'Aggravated_assault_rate', 'Property\ncrime': 'Property_crime','Property\ncrime\nrate':'Property_crime_rate','Burglary\nrate':'Burglary_rate', 'Larceny-\ntheft':'Larceny_theft','Larceny-\ntheft rate':'Larceny_theft_rate','Motor\nvehicle\ntheft':'Motor_vehicle_theft','Motor\nvehicle\ntheft\nrate':'Motor_vehicle_theft_rate'})
crimes_df
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
crimes_highest=crimes_df.sort_values(by=['Violent crime rate'], ascending=False)
crimes_highest
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 6   2006  299,398,484      1,435,123               479.3
# 3   2003  290,788,976      1,383,676               475.8
# 7   2007  301,621,157      1,422,970               471.8
# 5   2005  296,507,061      1,390,745               469.0
# 4   2004  293,656,842      1,360,088               463.2
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 12  2012  313,873,685      1,217,057               387.8
# 11  2011  311,587,816      1,206,005               387.1
# 16  2016  323,405,935      1,250,162               386.6
# 17  2017  325,147,121      1,247,917               383.8
# ...

# %% [markdown]
# ## 2000 had the highest violent crime rate, but 2001 had the highest number of violent crimes.

# %%
crimes_highestmurder=crimes_df.sort_values(by=['Murder nonnegligent manslaughter'], ascending=False)
crimes_highestmurder
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 16  2016  323,405,935      1,250,162               386.6
# 6   2006  299,398,484      1,435,123               479.3
# 17  2017  325,147,121      1,247,917               383.8
# 7   2007  301,621,157      1,422,970               471.8
# 5   2005  296,507,061      1,390,745               469.0
# 3   2003  290,788,976      1,383,676               475.8
# 8   2008  304,059,724      1,394,461               458.6
# 19  2019  328,239,523      1,203,808               366.7
# 18  2018  326,687,501      1,209,997               370.4
# 2   2002  287,973,924      1,423,677               494.4
# 4   2004  293,656,842      1,360,088               463.2
# 1   2001  285,317,559      1,439,480               504.5
# 15  2015  320,896,618      1,199,310               373.7
# 0   2000  281,421,906      1,425,486               506.5
# 9   2009  307,006,550      1,325,896               431.9
# ...

# %%
crimes_highestmurder_rate=crimes_df.sort_values(by=['Murder nonnegligent manslaughter rate'], ascending=False)
crimes_highestmurder_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 6   2006  299,398,484      1,435,123               479.3
# 3   2003  290,788,976      1,383,676               475.8
# 7   2007  301,621,157      1,422,970               471.8
# 2   2002  287,973,924      1,423,677               494.4
# 5   2005  296,507,061      1,390,745               469.0
# 1   2001  285,317,559      1,439,480               504.5
# 0   2000  281,421,906      1,425,486               506.5
# 4   2004  293,656,842      1,360,088               463.2
# 16  2016  323,405,935      1,250,162               386.6
# 8   2008  304,059,724      1,394,461               458.6
# 17  2017  325,147,121      1,247,917               383.8
# 18  2018  326,687,501      1,209,997               370.4
# 19  2019  328,239,523      1,203,808               366.7
# 9   2009  307,006,550      1,325,896               431.9
# 15  2015  320,896,618      1,199,310               373.7
# ...

# %% [markdown]
# ## 2016 had the highest murder count, but 2006 had the highest murder rate

# %%
crimes_highestrobbery=crimes_df.sort_values(by=['Robbery'], ascending=False)
crimes_highestrobbery
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 5   2005  296,507,061      1,390,745               469.0
# 3   2003  290,788,976      1,383,676               475.8
# 9   2009  307,006,550      1,325,896               431.9
# 0   2000  281,421,906      1,425,486               506.5
# 4   2004  293,656,842      1,360,088               463.2
# 10  2010  309,330,219      1,251,248               404.5
# 12  2012  313,873,685      1,217,057               387.8
# 11  2011  311,587,816      1,206,005               387.1
# 13  2013  316,497,531      1,168,298               369.1
# 16  2016  323,405,935      1,250,162               386.6
# ...

# %%
crimes_highestrobbery_rate=crimes_df.sort_values(by=['Robbery_rate'], ascending=False)
crimes_highestrobbery_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 6   2006  299,398,484      1,435,123               479.3
# 1   2001  285,317,559      1,439,480               504.5
# 7   2007  301,621,157      1,422,970               471.8
# 2   2002  287,973,924      1,423,677               494.4
# 8   2008  304,059,724      1,394,461               458.6
# 0   2000  281,421,906      1,425,486               506.5
# 3   2003  290,788,976      1,383,676               475.8
# 5   2005  296,507,061      1,390,745               469.0
# 4   2004  293,656,842      1,360,088               463.2
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 16  2016  323,405,935      1,250,162               386.6
# ...

# %% [markdown]
# ## 2006 had the highest robbery rate and number of robberies

# %%
crimes_highestassault=crimes_df.sort_values(by=['Aggravated_assault'], ascending=False)
crimes_highestassault
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 5   2005  296,507,061      1,390,745               469.0
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 8   2008  304,059,724      1,394,461               458.6
# 19  2019  328,239,523      1,203,808               366.7
# 9   2009  307,006,550      1,325,896               431.9
# 18  2018  326,687,501      1,209,997               370.4
# 17  2017  325,147,121      1,247,917               383.8
# 16  2016  323,405,935      1,250,162               386.6
# 10  2010  309,330,219      1,251,248               404.5
# ...

# %%
crimes_highestassault_rate=crimes_df.sort_values(by=['Aggravated_assault_rate'], ascending=False)
crimes_highestassault_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 0   2000  281,421,906      1,425,486               506.5
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 6   2006  299,398,484      1,435,123               479.3
# 5   2005  296,507,061      1,390,745               469.0
# 4   2004  293,656,842      1,360,088               463.2
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 19  2019  328,239,523      1,203,808               366.7
# 17  2017  325,147,121      1,247,917               383.8
# 16  2016  323,405,935      1,250,162               386.6
# 18  2018  326,687,501      1,209,997               370.4
# ...

# %% [markdown]
# ## 2000 had the highest number of Assaults and the highest Assault rate

# %%
crimes_highestprop=crimes_df.sort_values(by=['Property_crime'], ascending=False)
crimes_highestprop
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# 15  2015  320,896,618      1,199,310               373.7
# 16  2016  323,405,935      1,250,162               386.6
# 17  2017  325,147,121      1,247,917               383.8
# 18  2018  326,687,501      1,209,997               370.4
# 19  2019  328,239,523      1,203,808               366.7
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# ...

# %%
crimes_highestprop_rate=crimes_df.sort_values(by=['Property_crime_rate'], ascending=False)
crimes_highestprop_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 0   2000  281,421,906      1,425,486               506.5
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %% [markdown]
# ## 2007 had the most property crimes and 2001 had the highest rate for property crimes.

# %%
crimes_highestburglary=crimes_df.sort_values(by=['Burglary'], ascending=False)
crimes_highestburglary
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 11  2011  311,587,816      1,206,005               387.1
# 10  2010  309,330,219      1,251,248               404.5
# 5   2005  296,507,061      1,390,745               469.0
# 3   2003  290,788,976      1,383,676               475.8
# 2   2002  287,973,924      1,423,677               494.4
# 4   2004  293,656,842      1,360,088               463.2
# 1   2001  285,317,559      1,439,480               504.5
# 12  2012  313,873,685      1,217,057               387.8
# 0   2000  281,421,906      1,425,486               506.5
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
crimes_highestburglary_rate=crimes_df.sort_values(by=['Burglary_rate'], ascending=False)
crimes_highestburglary_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 2   2002  287,973,924      1,423,677               494.4
# 1   2001  285,317,559      1,439,480               504.5
# 3   2003  290,788,976      1,383,676               475.8
# 6   2006  299,398,484      1,435,123               479.3
# 8   2008  304,059,724      1,394,461               458.6
# 4   2004  293,656,842      1,360,088               463.2
# 0   2000  281,421,906      1,425,486               506.5
# 5   2005  296,507,061      1,390,745               469.0
# 7   2007  301,621,157      1,422,970               471.8
# 9   2009  307,006,550      1,325,896               431.9
# 11  2011  311,587,816      1,206,005               387.1
# 10  2010  309,330,219      1,251,248               404.5
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %% [markdown]
# ## 2008 had the most burglaries and 2002 had the highest burglary rate

# %%
crimes_highestlarceny=crimes_df.sort_values(by=['Larceny_theft'], ascending=False)
crimes_highestlarceny
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 1   2001  285,317,559      1,439,480               504.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 0   2000  281,421,906      1,425,486               506.5
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 12  2012  313,873,685      1,217,057               387.8
# 11  2011  311,587,816      1,206,005               387.1
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %%
crimes_highestlarceny_rate=crimes_df.sort_values(by=['Larceny_theft_rate'], ascending=False)
crimes_highestlarceny_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 1   2001  285,317,559      1,439,480               504.5
# 0   2000  281,421,906      1,425,486               506.5
# 2   2002  287,973,924      1,423,677               494.4
# 3   2003  290,788,976      1,383,676               475.8
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 11  2011  311,587,816      1,206,005               387.1
# 12  2012  313,873,685      1,217,057               387.8
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# ...

# %% [markdown]
# ## 2001 had the most larceny thefts and the highest rate for larceny thefts

# %%
crimes_highestmotor=crimes_df.sort_values(by=['Motor_vehicle_theft'], ascending=False)
crimes_highestmotor
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 17  2017  325,147,121      1,247,917               383.8
# 16  2016  323,405,935      1,250,162               386.6
# 18  2018  326,687,501      1,209,997               370.4
# 10  2010  309,330,219      1,251,248               404.5
# 12  2012  313,873,685      1,217,057               387.8
# 19  2019  328,239,523      1,203,808               366.7
# 11  2011  311,587,816      1,206,005               387.1
# 15  2015  320,896,618      1,199,310               373.7
# 13  2013  316,497,531      1,168,298               369.1
# 14  2014  318,907,401      1,153,022               361.6
# 3   2003  290,788,976      1,383,676               475.8
# 2   2002  287,973,924      1,423,677               494.4
# 4   2004  293,656,842      1,360,088               463.2
# ...

# %%
crimes_highestmotor_rate=crimes_df.sort_values(by=['Motor_vehicle_theft_rate'], ascending=False)
crimes_highestmotor_rate
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 3   2003  290,788,976      1,383,676               475.8
# 2   2002  287,973,924      1,423,677               494.4
# 1   2001  285,317,559      1,439,480               504.5
# 4   2004  293,656,842      1,360,088               463.2
# 5   2005  296,507,061      1,390,745               469.0
# 0   2000  281,421,906      1,425,486               506.5
# 6   2006  299,398,484      1,435,123               479.3
# 7   2007  301,621,157      1,422,970               471.8
# 8   2008  304,059,724      1,394,461               458.6
# 9   2009  307,006,550      1,325,896               431.9
# 10  2010  309,330,219      1,251,248               404.5
# 17  2017  325,147,121      1,247,917               383.8
# 16  2016  323,405,935      1,250,162               386.6
# 12  2012  313,873,685      1,217,057               387.8
# 18  2018  326,687,501      1,209,997               370.4
# ...

# %% [markdown]
# ## 2008 had the most motor vehicle thefts and 2003 had the highest rate of motor vehicle thefts.

# %% [markdown]
# ## 2001 had the most problems with the most violent crimes, the highest property crimes rate, the most larceny thefts, and the highest larceny theft rate.

# %% [markdown]
# ## 2000 and 2006 each appeared 3 times. 2000 had the highest violent crime rate, the most assaults, and the highest assault rate. 200 had the highest number of robberies, the highest robbery rate, and the highest murder rate.

# %%
crimes_pop=crimes_df.sort_values(by=['Population'], ascending=False)
crimes_pop
# Out:
#     Year   Population Violent Crimes  Violent crime rate  \
# 19  2019  328,239,523      1,203,808               366.7
# 18  2018  326,687,501      1,209,997               370.4
# 17  2017  325,147,121      1,247,917               383.8
# 16  2016  323,405,935      1,250,162               386.6
# 15  2015  320,896,618      1,199,310               373.7
# 14  2014  318,907,401      1,153,022               361.6
# 13  2013  316,497,531      1,168,298               369.1
# 12  2012  313,873,685      1,217,057               387.8
# 11  2011  311,587,816      1,206,005               387.1
# 10  2010  309,330,219      1,251,248               404.5
# 9   2009  307,006,550      1,325,896               431.9
# 8   2008  304,059,724      1,394,461               458.6
# 7   2007  301,621,157      1,422,970               471.8
# 6   2006  299,398,484      1,435,123               479.3
# 5   2005  296,507,061      1,390,745               469.0
# ...

# %% [markdown]
# ## The population steadily increases from 2000 to 2019
